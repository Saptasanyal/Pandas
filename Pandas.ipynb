# %% [markdown]
# The Pandas library in Python stands as the most utilized library within the Python community, serving as an essential tool for data manipulation across various aspects of data analysis and machine learning. Its significance extends to virtually every data-related operation, including data visualization and machine learning projects, where data manipulation is an inevitable requirement. This article aims to outline the key Pandas functions that are indispensable for daily tasks, providing a comprehensive toolkit for routine data manipulation activities. These functions are designed to meet the regular needs of data analysts and machine learning practitioners, ensuring efficient and effective data handling for a wide range of projects.

# %%
import numpy as np
import pandas as pd
#pd.set_option('display.max_columns', 100) # Now, when you print a DataFrame, Pandas will attempt to display up to 100 columns if they exist.

# %% [markdown]
# **1. pd.read_csv, pd.read_excel**
#
# he functions read_csv and read_excel are fundamental in the Pandas library, serving as essential tools for importing data into Python. These functions are intuitively named to reflect their purpose: read_csv is used to import data from CSV (Comma-Separated Values) files, while read_excel is utilized for reading data from Excel files, converting them into Pandas DataFrame format. In virtually every project I have undertaken, I have found myself using at least one of these functions to load data. For instance, in reading the FIFA dataset, the read_csv function plays a crucial role, demonstrating its practicality and ease of use in data analysis tasks.

# %%
df = pd.read_csv("/content/fifa.csv")

# %%
df
# Out:
#        Unnamed: 0  sofifa_id  \
# 0               0     158023
# 1               1      20801
# 2               2       9014
# 3               3      41236
# 4               4     167495
# ...           ...        ...
# 16150       16150     220806
# 16151       16151     225509
# 16152       16152     217591
# 16153       16153     222947
# 16154       16154     201197
#
#                                               player_url         short_name  \
# 0      https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2      https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3      https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4      https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                  ...                ...
# 16150  https://sofifa.com/player/220806/ellis-redman/...          E. Redman
# 16151  https://sofifa.com/player/225509/aaron-collins...         A. Collins
# 16152  https://sofifa.com/player/217591/piotr-zemlo/1...           P. Żemło
# 16153  https://sofifa.com/player/222947/tom-davies/15...          T. Davies
# 16154  https://sofifa.com/player/201197/paul-tisdale/...         P. Tisdale
#
#                                  long_name  age         dob  height_cm  \
# 0           Lionel Andrés Messi Cuccittini   27  1987-06-24        169
# 1      Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05        185
# 2                             Arjen Robben   30  1984-01-23        180
# 3                       Zlatan Ibrahimović   32  1981-10-03        195
# 4                             Manuel Neuer   28  1986-03-27        193
# ...                                    ...  ...         ...        ...
# 16150                         Ellis Redman   17  1996-09-26        187
# 16151                        Aaron Collins   17  1997-06-01        178
# 16152                          Piotr Żemło   18  1995-07-10        190
# 16153                           Tom Davies   22  1992-04-18        180
# 16154                         Paul Tisdale   41  1973-01-14        175
#
#        weight_kg  nationality  ... mentality_penalties mentality_composure  \
# 0             67    Argentina  ...                  76                 NaN
# 1             80     Portugal  ...                  85                 NaN
# 2             80  Netherlands  ...                  80                 NaN
# 3             95       Sweden  ...                  91                 NaN
# 4             92      Germany  ...                  37                 NaN
# ...          ...          ...  ...                 ...                 ...
# 16150         81        Wales  ...                  31                 NaN
# 16151         57        Wales  ...                  47                 NaN
# 16152         76       Poland  ...                  31                 NaN
# 16153         70      England  ...                  21                 NaN
# 16154         72        Malta  ...                  55                 NaN
#
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 0                     25                         21                        20
# 1                     22                         31                        23
# 2                     29                         26                        26
# 3                     25                         41                        27
# 4                     25                         25                        25
# ...                  ...                        ...                       ...
# 16150                 38                         40                        35
# 16151                 25                         25                        25
# 16152                 54                         52                        51
# 16153                 36                         34                        35
# 16154                 27                         34                        29
#
#        goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 0                       6                    11                  15
# 1                       7                    11                  15
# 2                      10                     8                  11
# 3                      13                    15                  10
# 4                      87                    85                  92
# ...                   ...                   ...                 ...
# 16150                  12                     6                  15
# 16151                  13                    11                  12
# 16152                   8                    14                   7
# 16153                  15                    13                   6
# 16154                   5                     6                  14
#
#       goalkeeping_positioning  goalkeeping_reflexes
# 0                          14                     8
# 1                          14                    11
# 2                           5                    15
# 3                           9                    12
# 4                          90                    86
# ...                       ...                   ...
# 16150                       8                     6
# 16151                      15                    11
# 16152                      10                     9
# 16153                      11                     9
# 16154                       8                    13
#
# [16155 rows x 81 columns]

# %% [markdown]
# A .txt file can also be read using .read_csv() function using the following syntax:

# %%
#data = pd.read_csv("/content/Machine_Learning.txt", sep=" ")

# %%
#data

# %% [markdown]
# It is also common to use .head() function after read_csv or read_excel to see the data frame. By default, it shows the first 5 rows of the DataFrame. Here I am showing the first five rows of the DataFrame df above:

# %%
df.head()
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality  ... mentality_penalties  \
# 0        169         67    Argentina  ...                  76
# 1        185         80     Portugal  ...                  85
# 2        180         80  Netherlands  ...                  80
# 3        195         95       Sweden  ...                  91
# 4        193         92      Germany  ...                  37
#
#   mentality_composure  defending_marking  defending_standing_tackle  \
# 0                 NaN                 25                         21
# 1                 NaN                 22                         31
# 2                 NaN                 29                         26
# 3                 NaN                 25                         41
# 4                 NaN                 25                         25
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        20                   6                    11
# 1                        23                   7                    11
# 2                        26                  10                     8
# 3                        27                  13                    15
# 4                        25                  87                    85
#
#   goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes
# 0                  15                      14                     8
# 1                  15                      14                    11
# 2                  11                       5                    15
# 3                  10                       9                    12
# 4                  92                      90                    86
#
# [5 rows x 81 columns]

# %% [markdown]
# If you want a specific number of rows instead of five rows, you can specify that. If I wanted 7 rows I would have mentioned in the .head() function as a parameter.

# %%
df.head(11)
# Out:
#     Unnamed: 0  sofifa_id                                         player_url  \
# 0            0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1            1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2            2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3            3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4            4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5            5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6            6         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 7            7     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8            8       7826  https://sofifa.com/player/7826/robin-van-persi...
# 9            9     121944  https://sofifa.com/player/121944/bastian-schwe...
# 10          10     156616  https://sofifa.com/player/156616/franck-ribery...
#
#            short_name                            long_name  age         dob  \
# 0            L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1   Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2           A. Robben                         Arjen Robben   30  1984-01-23
# 3      Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4            M. Neuer                         Manuel Neuer   28  1986-03-27
# 5           L. Suárez             Luis Alberto Suárez Díaz   27  1987-01-24
# 6             Iniesta                 Andrés Iniesta Luján   30  1984-05-11
# 7           E. Hazard                          Eden Hazard   23  1991-01-07
# 8       R. van Persie                     Robin van Persie   30  1983-08-06
# 9   B. Schweinsteiger               Bastian Schweinsteiger   29  1984-08-01
# 10          F. Ribéry                  Franck Bilal Ribéry   31  1983-04-07
#
#     height_cm  weight_kg  nationality  ... mentality_penalties  \
# 0         169         67    Argentina  ...                  76
# 1         185         80     Portugal  ...                  85
# 2         180         80  Netherlands  ...                  80
# 3         195         95       Sweden  ...                  91
# 4         193         92      Germany  ...                  37
# 5         181         81      Uruguay  ...                  85
# 6         170         65        Spain  ...                  71
# 7         173         74      Belgium  ...                  86
# 8         187         71  Netherlands  ...                  86
# 9         183         79      Germany  ...                  81
# 10        170         72       France  ...                  80
#
#    mentality_composure  defending_marking  defending_standing_tackle  \
# 0                  NaN                 25                         21
# 1                  NaN                 22                         31
# 2                  NaN                 29                         26
# 3                  NaN                 25                         41
# 4                  NaN                 25                         25
# 5                  NaN                 30                         45
# 6                  NaN                 57                         57
# 7                  NaN                 25                         27
# 8                  NaN                 23                         32
# 9                  NaN                 69                         80
# 10                 NaN                 25                         25
#
#     defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                         20                   6                    11
# 1                         23                   7                    11
# 2                         26                  10                     8
# 3                         27                  13                    15
# 4                         25                  87                    85
# 5                         38                  27                    25
# 6                         56                   6                    13
# 7                         22                  11                    12
# 8                         21                   9                    10
# 9                         77                  14                    14
# 10                        26                  15                     6
#
#    goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes
# 0                   15                      14                     8
# 1                   15                      14                    11
# 2                   11                       5                    15
# 3                   10                       9                    12
# 4                   92                      90                    86
# 5                   31                      33                    37
# 6                    6                      13                     7
# 7                    6                       8                     8
# 8                    5                       7                     8
# 9                   13                      13                    11
# 10                   9                       7                    10
#
# [11 rows x 81 columns]

# %%
df.head(10)
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5           5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6           6         41  https://sofifa.com/player/41/andres-iniesta-lu...
# 7           7     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8           8       7826  https://sofifa.com/player/7826/robin-van-persi...
# 9           9     121944  https://sofifa.com/player/121944/bastian-schwe...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
# 5          L. Suárez             Luis Alberto Suárez Díaz   27  1987-01-24
# 6            Iniesta                 Andrés Iniesta Luján   30  1984-05-11
# 7          E. Hazard                          Eden Hazard   23  1991-01-07
# 8      R. van Persie                     Robin van Persie   30  1983-08-06
# 9  B. Schweinsteiger               Bastian Schweinsteiger   29  1984-08-01
#
#    height_cm  weight_kg  nationality  ... mentality_penalties  \
# 0        169         67    Argentina  ...                  76
# 1        185         80     Portugal  ...                  85
# 2        180         80  Netherlands  ...                  80
# 3        195         95       Sweden  ...                  91
# 4        193         92      Germany  ...                  37
# 5        181         81      Uruguay  ...                  85
# 6        170         65        Spain  ...                  71
# 7        173         74      Belgium  ...                  86
# 8        187         71  Netherlands  ...                  86
# 9        183         79      Germany  ...                  81
#
#   mentality_composure  defending_marking  defending_standing_tackle  \
# 0                 NaN                 25                         21
# 1                 NaN                 22                         31
# 2                 NaN                 29                         26
# 3                 NaN                 25                         41
# 4                 NaN                 25                         25
# 5                 NaN                 30                         45
# 6                 NaN                 57                         57
# 7                 NaN                 25                         27
# 8                 NaN                 23                         32
# 9                 NaN                 69                         80
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        20                   6                    11
# 1                        23                   7                    11
# 2                        26                  10                     8
# 3                        27                  13                    15
# 4                        25                  87                    85
# 5                        38                  27                    25
# 6                        56                   6                    13
# 7                        22                  11                    12
# 8                        21                   9                    10
# 9                        77                  14                    14
#
#   goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes
# 0                  15                      14                     8
# 1                  15                      14                    11
# 2                  11                       5                    15
# 3                  10                       9                    12
# 4                  92                      90                    86
# 5                  31                      33                    37
# 6                   6                      13                     7
# 7                   6                       8                     8
# 8                   5                       7                     8
# 9                  13                      13                    11
#
# [10 rows x 81 columns]

# %% [markdown]
# Similarly last 5 values are given by tail()

# %%
df.tail()
# Out:
#        Unnamed: 0  sofifa_id  \
# 16150       16150     220806
# 16151       16151     225509
# 16152       16152     217591
# 16153       16153     222947
# 16154       16154     201197
#
#                                               player_url  short_name  \
# 16150  https://sofifa.com/player/220806/ellis-redman/...   E. Redman
# 16151  https://sofifa.com/player/225509/aaron-collins...  A. Collins
# 16152  https://sofifa.com/player/217591/piotr-zemlo/1...    P. Żemło
# 16153  https://sofifa.com/player/222947/tom-davies/15...   T. Davies
# 16154  https://sofifa.com/player/201197/paul-tisdale/...  P. Tisdale
#
#            long_name  age         dob  height_cm  weight_kg nationality  ...  \
# 16150   Ellis Redman   17  1996-09-26        187         81       Wales  ...
# 16151  Aaron Collins   17  1997-06-01        178         57       Wales  ...
# 16152    Piotr Żemło   18  1995-07-10        190         76      Poland  ...
# 16153     Tom Davies   22  1992-04-18        180         70     England  ...
# 16154   Paul Tisdale   41  1973-01-14        175         72       Malta  ...
#
#       mentality_penalties mentality_composure  defending_marking  \
# 16150                  31                 NaN                 38
# 16151                  47                 NaN                 25
# 16152                  31                 NaN                 54
# 16153                  21                 NaN                 36
# 16154                  55                 NaN                 27
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 16150                         40                        35
# 16151                         25                        25
# 16152                         52                        51
# 16153                         34                        35
# 16154                         34                        29
#
#        goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 16150                  12                     6                  15
# 16151                  13                    11                  12
# 16152                   8                    14                   7
# 16153                  15                    13                   6
# 16154                   5                     6                  14
#
#       goalkeeping_positioning  goalkeeping_reflexes
# 16150                       8                     6
# 16151                      15                    11
# 16152                      10                     9
# 16153                      11                     9
# 16154                       8                    13
#
# [5 rows x 81 columns]

# %% [markdown]
# **2. df.columns**
#
#
# When you have a big dataset like that it can be hard to see all the columns. using .columns function, you can print out all the columns of the dataset:

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'sofifa_id', 'player_url', 'short_name', 'long_name',
#        'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club_name',
#        'league_name', 'league_rank', 'overall', 'potential', 'value_eur',
#        'wage_eur', 'player_positions', 'preferred_foot',
#        'international_reputation', 'weak_foot', 'skill_moves', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur', 'player_tags',
#        'team_position', 'team_jersey_number', 'loaned_from', 'joined',
#        'contract_valid_until', 'nation_position', 'nation_jersey_number',
#        'pace', 'shooting', 'passing', 'dribbling', 'defending', 'physic',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed',
#        'gk_positioning', 'player_traits', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes'],
#       dtype='object')

# %% [markdown]
# **3. df.drop()**
#
#
# You can drop some unnecessary columns using df.drop(). In this dataset we have so many columns we are not going to use all of them for this tutorial. So, we can easily drop some:

# %%
df = df.drop(columns=['Unnamed: 0', 'weak_foot', 'real_face'])

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4               M. Neuer                         Manuel Neuer   28
# ...                  ...                                  ...  ...
# 16150          E. Redman                         Ellis Redman   17
# 16151         A. Collins                        Aaron Collins   17
# 16152           P. Żemło                          Piotr Żemło   18
# 16153          T. Davies                           Tom Davies   22
# 16154         P. Tisdale                         Paul Tisdale   41
#
#               dob  height_cm  weight_kg  nationality            club_name  \
# 0      1987-06-24        169         67    Argentina         FC Barcelona
# 1      1985-02-05        185         80     Portugal          Real Madrid
# 2      1984-01-23        180         80  Netherlands    FC Bayern München
# 3      1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4      1986-03-27        193         92      Germany    FC Bayern München
# ...           ...        ...        ...          ...                  ...
# 16150  1996-09-26        187         81        Wales       Newport County
# 16151  1997-06-01        178         57        Wales       Newport County
# 16152  1995-07-10        190         76       Poland         Wisła Kraków
# 16153  1992-04-18        180         70      England       Fleetwood Town
# 16154  1973-01-14        175         72        Malta          Exeter City
#
#        ... mentality_penalties  mentality_composure  defending_marking  \
# 0      ...                  76                  NaN                 25
# 1      ...                  85                  NaN                 22
# 2      ...                  80                  NaN                 29
# 3      ...                  91                  NaN                 25
# 4      ...                  37                  NaN                 25
# ...    ...                 ...                  ...                ...
# 16150  ...                  31                  NaN                 38
# 16151  ...                  47                  NaN                 25
# 16152  ...                  31                  NaN                 54
# 16153  ...                  21                  NaN                 36
# 16154  ...                  55                  NaN                 27
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             21                        20
# 1                             31                        23
# 2                             26                        26
# 3                             41                        27
# 4                             25                        25
# ...                          ...                       ...
# 16150                         40                        35
# 16151                         25                        25
# 16152                         52                        51
# 16153                         34                        35
# 16154                         34                        29
#
#        goalkeeping_diving goalkeeping_handling goalkeeping_kicking  \
# 0                       6                   11                  15
# 1                       7                   11                  15
# 2                      10                    8                  11
# 3                      13                   15                  10
# 4                      87                   85                  92
# ...                   ...                  ...                 ...
# 16150                  12                    6                  15
# 16151                  13                   11                  12
# 16152                   8                   14                   7
# 16153                  15                   13                   6
# 16154                   5                    6                  14
#
#        goalkeeping_positioning  goalkeeping_reflexes
# 0                           14                     8
# 1                           14                    11
# 2                            5                    15
# 3                            9                    12
# 4                           90                    86
# ...                        ...                   ...
# 16150                        8                     6
# 16151                       15                    11
# 16152                       10                     9
# 16153                       11                     9
# 16154                        8                    13
#
# [16155 rows x 78 columns]

# %% [markdown]
# **4. .len()**
#
#
# Provides with the length of the DataFrame. Let’s see an example:

# %%
len(df)
# Out:
# 16155

# %% [markdown]
# This DataFrame has 16155 rows of data

# %% [markdown]
# **5. df.query()**
#
# You can filter or query using a boolean expression. I will use ‘shooting’ and ‘passing’ columns for this example. Here I am checking for which rows ‘shooting’ is bigger than ‘passing’.

# %%
df.query("shooting > passing")
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 5         176580  https://sofifa.com/player/176580/luis-suarez/1...
# ...          ...                                                ...
# 16113     224502  https://sofifa.com/player/224502/billy-whiteho...
# 16116     223905   https://sofifa.com/player/223905/perry-ng/150002
# 16123     209403  https://sofifa.com/player/209403/jamie-allen/1...
# 16143     220549  https://sofifa.com/player/220549/liam-davies/1...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 5              L. Suárez             Luis Alberto Suárez Díaz   27
# ...                  ...                                  ...  ...
# 16113      B. Whitehouse             Billy Haywood Whitehouse   18
# 16116              P. Ng                             Perry Ng   18
# 16123           J. Allen                          Jamie Allen   19
# 16143          L. Davies                          Liam Davies   17
# 16151         A. Collins                        Aaron Collins   17
#
#               dob  height_cm  weight_kg  nationality            club_name  \
# 0      1987-06-24        169         67    Argentina         FC Barcelona
# 1      1985-02-05        185         80     Portugal          Real Madrid
# 2      1984-01-23        180         80  Netherlands    FC Bayern München
# 3      1981-10-03        195         95       Sweden  Paris Saint-Germain
# 5      1987-01-24        181         81      Uruguay         FC Barcelona
# ...           ...        ...        ...          ...                  ...
# 16113  1996-06-13        180         72      England     Doncaster Rovers
# 16116  1996-04-27        180         77      England      Crewe Alexandra
# 16123  1995-05-25        170         69      England       Fleetwood Town
# 16143  1996-07-02        183         70      England      Tranmere Rovers
# 16151  1997-06-01        178         57        Wales       Newport County
#
#        ... mentality_penalties  mentality_composure  defending_marking  \
# 0      ...                  76                  NaN                 25
# 1      ...                  85                  NaN                 22
# 2      ...                  80                  NaN                 29
# 3      ...                  91                  NaN                 25
# 5      ...                  85                  NaN                 30
# ...    ...                 ...                  ...                ...
# 16113  ...                  52                  NaN                 20
# 16116  ...                  33                  NaN                 40
# 16123  ...                  41                  NaN                 20
# 16143  ...                  59                  NaN                 25
# 16151  ...                  47                  NaN                 25
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 0                             21                        20
# 1                             31                        23
# 2                             26                        26
# 3                             41                        27
# 5                             45                        38
# ...                          ...                       ...
# 16113                         23                        29
# 16116                         48                        49
# 16123                         23                        24
# 16143                         25                        25
# 16151                         25                        25
#
#        goalkeeping_diving goalkeeping_handling goalkeeping_kicking  \
# 0                       6                   11                  15
# 1                       7                   11                  15
# 2                      10                    8                  11
# 3                      13                   15                  10
# 5                      27                   25                  31
# ...                   ...                  ...                 ...
# 16113                   9                   11                  10
# 16116                   9                    5                   7
# 16123                  10                   14                   5
# 16143                   7                   14                  11
# 16151                  13                   11                  12
#
#        goalkeeping_positioning  goalkeeping_reflexes
# 0                           14                     8
# 1                           14                    11
# 2                            5                    15
# 3                            9                    12
# 5                           33                    37
# ...                        ...                   ...
# 16113                        7                     5
# 16116                       15                     6
# 16123                       11                     8
# 16143                       12                    13
# 16151                       15                    11
#
# [4196 rows x 78 columns]

# %% [markdown]
# This will return the rows only where the shooting is bigger than passing.
#
# **6. df.iloc()**
#
#
# This function takes as a parameter the rows and column indices and gives you the subset of the DataFrame accordingly. Here I am taking the first 10 rows of data and index 5th to index 10th columns:

# %%
df.iloc[:10, 5:10]
# Out:
#           dob  height_cm  weight_kg  nationality            club_name
# 0  1987-06-24        169         67    Argentina         FC Barcelona
# 1  1985-02-05        185         80     Portugal          Real Madrid
# 2  1984-01-23        180         80  Netherlands    FC Bayern München
# 3  1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4  1986-03-27        193         92      Germany    FC Bayern München
# 5  1987-01-24        181         81      Uruguay         FC Barcelona
# 6  1984-05-11        170         65        Spain         FC Barcelona
# 7  1991-01-07        173         74      Belgium              Chelsea
# 8  1983-08-06        187         71  Netherlands    Manchester United
# 9  1984-08-01        183         79      Germany    FC Bayern München

# %% [markdown]
# **7. df.loc()**
#
# This function does almost the similar operation as .iloc() function. But here we can specify exactly which row index we want and also the name of the columns we want in our subset. Here is an example:

# %%
df.loc[[3, 10, 14, 23], ['nationality', 'weight_kg', "height_cm"]]
# Out:
#    nationality  weight_kg  height_cm
# 3       Sweden         95        195
# 10      France         72        170
# 14     Germany         66        170
# 23   Argentina         70        180

# %% [markdown]
# Look at the row indices. We only have the 3rd, 10th, 14th, and 23rd rows. On the other hand, for columns, we only have the specified columns.
#
# **8. df[‘’].dtypes**
#
#
# Another very basic and widely used functions. Because it is necessary to know the data types of the variables before we dive into the analysis, visualization, or predictive modeling. I am getting the data type of the ‘height_cm’ column using .dtypes function here:

# %%
df.height_cm.dtypes
# Out:
# dtype('int64')

# %% [markdown]
# You have the option to get the data type of each and every column as well using this syntax:

# %%
df.dtypes
# Out:
# sofifa_id                   int64
# player_url                 object
# short_name                 object
# long_name                  object
# age                         int64
#                             ...
# goalkeeping_diving          int64
# goalkeeping_handling        int64
# goalkeeping_kicking         int64
# goalkeeping_positioning     int64
# goalkeeping_reflexes        int64
# Length: 78, dtype: object

# %% [markdown]
# **9. df.select_dtypes()**
#
# You can select the variables or columns of a certain data type using this function. For example, I want to select the columns with data types ‘int64’ only. Here is how to do that:

# %%
df.select_dtypes(include='int64')
# Out:
#        sofifa_id  age  height_cm  weight_kg  overall  potential  value_eur  \
# 0         158023   27        169         67       93         95  100500000
# 1          20801   29        185         80       92         92   79000000
# 2           9014   30        180         80       90         90   54500000
# 3          41236   32        195         95       90         90   52500000
# 4         167495   28        193         92       90         90   63500000
# ...          ...  ...        ...        ...      ...        ...        ...
# 16150     220806   17        187         81       41         61      20000
# 16151     225509   17        178         57       41         50      30000
# 16152     217591   18        190         76       40         50      15000
# 16153     222947   22        180         70       40         49      15000
# 16154     201197   41        175         72       40         40          0
#
#        wage_eur  international_reputation  skill_moves  ...  mentality_vision  \
# 0        550000                         5            4  ...                90
# 1        375000                         5            5  ...                81
# 2        275000                         5            4  ...                84
# 3        275000                         5            4  ...                83
# 4        300000                         5            1  ...                20
# ...         ...                       ...          ...  ...               ...
# 16150      2000                         1            2  ...                22
# 16151      2000                         1            3  ...                39
# 16152      2000                         1            2  ...                21
# 16153      2000                         1            2  ...                25
# 16154      2000                         1            2  ...                41
#
#        mentality_penalties  defending_marking  defending_standing_tackle  \
# 0                       76                 25                         21
# 1                       85                 22                         31
# 2                       80                 29                         26
# 3                       91                 25                         41
# 4                       37                 25                         25
# ...                    ...                ...                        ...
# 16150                   31                 38                         40
# 16151                   47                 25                         25
# 16152                   31                 54                         52
# 16153                   21                 36                         34
# 16154                   55                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                   6                    11
# 1                            23                   7                    11
# 2                            26                  10                     8
# 3                            27                  13                    15
# 4                            25                  87                    85
# ...                         ...                 ...                   ...
# 16150                        35                  12                     6
# 16151                        25                  13                    11
# 16152                        51                   8                    14
# 16153                        35                  15                    13
# 16154                        29                   5                     6
#
#        goalkeeping_kicking  goalkeeping_positioning  goalkeeping_reflexes
# 0                       15                       14                     8
# 1                       15                       14                    11
# 2                       11                        5                    15
# 3                       10                        9                    12
# 4                       92                       90                    86
# ...                    ...                      ...                   ...
# 16150                   15                        8                     6
# 16151                   12                       15                    11
# 16152                    7                       10                     9
# 16153                    6                       11                     9
# 16154                   14                        8                    13
#
# [16155 rows x 43 columns]

# %% [markdown]
# We got all the columns that have the data type ‘int64’. If we use ‘exclude’ instead of ‘include’ in the ‘select_dtypes’ function, we will get the columns that do not have the data type ‘int64’:

# %%
df.select_dtypes(exclude='int64')
# Out:
#                                               player_url         short_name  \
# 0      https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2      https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3      https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4      https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                  ...                ...
# 16150  https://sofifa.com/player/220806/ellis-redman/...          E. Redman
# 16151  https://sofifa.com/player/225509/aaron-collins...         A. Collins
# 16152  https://sofifa.com/player/217591/piotr-zemlo/1...           P. Żemło
# 16153  https://sofifa.com/player/222947/tom-davies/15...          T. Davies
# 16154  https://sofifa.com/player/201197/paul-tisdale/...         P. Tisdale
#
#                                  long_name         dob  nationality  \
# 0           Lionel Andrés Messi Cuccittini  1987-06-24    Argentina
# 1      Cristiano Ronaldo dos Santos Aveiro  1985-02-05     Portugal
# 2                             Arjen Robben  1984-01-23  Netherlands
# 3                       Zlatan Ibrahimović  1981-10-03       Sweden
# 4                             Manuel Neuer  1986-03-27      Germany
# ...                                    ...         ...          ...
# 16150                         Ellis Redman  1996-09-26        Wales
# 16151                        Aaron Collins  1997-06-01        Wales
# 16152                          Piotr Żemło  1995-07-10       Poland
# 16153                           Tom Davies  1992-04-18      England
# 16154                         Paul Tisdale  1973-01-14        Malta
#
#                  club_name                  league_name  league_rank  \
# 0             FC Barcelona       Spain Primera Division          1.0
# 1              Real Madrid       Spain Primera Division          1.0
# 2        FC Bayern München         German 1. Bundesliga          1.0
# 3      Paris Saint-Germain               French Ligue 1          1.0
# 4        FC Bayern München         German 1. Bundesliga          1.0
# ...                    ...                          ...          ...
# 16150       Newport County           English League Two          4.0
# 16151       Newport County           English League Two          4.0
# 16152         Wisła Kraków  Polish T-Mobile Ekstraklasa          1.0
# 16153       Fleetwood Town           English League One          3.0
# 16154          Exeter City           English League Two          4.0
#
#       player_positions preferred_foot  ... defending physic  gk_diving  \
# 0                   CF           Left  ...      27.0   63.0        NaN
# 1               LW, LM          Right  ...      32.0   79.0        NaN
# 2           RM, LM, RW           Left  ...      32.0   64.0        NaN
# 3                   ST          Right  ...      34.0   86.0        NaN
# 4                   GK          Right  ...       NaN    NaN       87.0
# ...                ...            ...  ...       ...    ...        ...
# 16150               CB          Right  ...      39.0   53.0        NaN
# 16151               ST          Right  ...      27.0   41.0        NaN
# 16152           LM, LB           Left  ...      52.0   68.0        NaN
# 16153               CB          Right  ...      35.0   61.0        NaN
# 16154          CM, CAM          Right  ...      31.0   33.0        NaN
#
#       gk_handling gk_kicking  gk_reflexes gk_speed gk_positioning  \
# 0             NaN        NaN          NaN      NaN            NaN
# 1             NaN        NaN          NaN      NaN            NaN
# 2             NaN        NaN          NaN      NaN            NaN
# 3             NaN        NaN          NaN      NaN            NaN
# 4            85.0       92.0         86.0     60.0           90.0
# ...           ...        ...          ...      ...            ...
# 16150         NaN        NaN          NaN      NaN            NaN
# 16151         NaN        NaN          NaN      NaN            NaN
# 16152         NaN        NaN          NaN      NaN            NaN
# 16153         NaN        NaN          NaN      NaN            NaN
# 16154         NaN        NaN          NaN      NaN            NaN
#
#                                            player_traits mentality_composure
# 0      Finesse Shot, Speed Dribbler (AI), One Club Pl...                 NaN
# 1      Power Free-Kick, Flair, Long Shot Taker (AI), ...                 NaN
# 2      Diver, Injury Prone, Avoids Using Weaker Foot,...                 NaN
# 3      Power Free-Kick, Leadership, Flair, Long Shot ...                 NaN
# 4          GK Up for Corners, GK Long Throw, 1-on-1 Rush                 NaN
# ...                                                  ...                 ...
# 16150                                                NaN                 NaN
# 16151                                                NaN                 NaN
# 16152                                                NaN                 NaN
# 16153                                                NaN                 NaN
# 16154                       Injury Prone, Playmaker (AI)                 NaN
#
# [16155 rows x 35 columns]

# %% [markdown]
# Here is part of the output. Look, the variables are not integers. You may think that the ‘random_col’ column is integers. But if you check its data type, you will see that it looks integers but its data type is different. Please feel free to check.
#
# **10. df.insert()**
#
# As the name of the function suggests, it inserts a column in the specified position. To demonstrate that I will first create an array of random numbers that have the length of our DataFrame:

# %%
random_col = np.random.randint(100, size=len(df))

# %% [markdown]
# I will insert this array as a column in the DataFrame df at column 3 position. Remember, the column index starts from zero.

# %%
df.insert(45, 'random_col', random_col)

# %% [markdown]
# Here is the part of the DataFrame again:

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality            club_name  ...  \
# 0        169         67    Argentina         FC Barcelona  ...
# 1        185         80     Portugal          Real Madrid  ...
# 2        180         80  Netherlands    FC Bayern München  ...
# 3        195         95       Sweden  Paris Saint-Germain  ...
# 4        193         92      Germany    FC Bayern München  ...
#
#   mentality_penalties  mentality_composure  defending_marking  \
# 0                  76                  NaN                 25
# 1                  85                  NaN                 22
# 2                  80                  NaN                 29
# 3                  91                  NaN                 25
# 4                  37                  NaN                 25
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         21                        20                   6
# 1                         31                        23                   7
# 2                         26                        26                  10
# 3                         41                        27                  13
# 4                         25                        25                  87
#
#   goalkeeping_handling goalkeeping_kicking  goalkeeping_positioning  \
# 0                   11                  15                       14
# 1                   11                  15                       14
# 2                    8                  11                        5
# 3                   15                  10                        9
# 4                   85                  92                       90
#
#    goalkeeping_reflexes
# 0                     8
# 1                    11
# 2                    15
# 3                    12
# 4                    86
#
# [5 rows x 80 columns]

# %% [markdown]
# Script for Ads:
# Look, the column ‘random_col’ is inserted at position three.
#
# **11. df[‘’].cumsum()**
#
# It provides you with the cumulative sum. Let me explain with an example. I am going to use the ‘value_eur’ and ‘wage_eur’columns for this example. Here is the code:

# %%
df[['value_eur', 'wage_eur']].cumsum()
# Out:
#          value_eur   wage_eur
# 0        100500000     550000
# 1        179500000     925000
# 2        234000000    1200000
# 3        286500000    1475000
# 4        350000000    1775000
# ...            ...        ...
# 16150  17138496000  210919000
# 16151  17138526000  210921000
# 16152  17138541000  210923000
# 16153  17138556000  210925000
# 16154  17138556000  210927000
#
# [16155 rows x 2 columns]

# %% [markdown]
# As you can see in every row it provides you with the cumulative sum of all the values of the previous rows.
#
# **12. df.sample()**
#
# When the size of the dataset is too big, you can take a representative sample from it to perform the analysis and predictive modeling. That may save you some time. Also, too much data may ruin the visualization sometimes. we can use this function to get a certain number of data points or a certain fraction or data point. Here I am taking a sample of 200 data points from the FIFA dataset. It takes a random sample.

# %%
df.sample(n = 200)
# Out:
#        sofifa_id                                         player_url  \
# 10226     212678  https://sofifa.com/player/212678/ludwig-august...
# 640       156722  https://sofifa.com/player/156722/mathieu-flami...
# 4351      193246  https://sofifa.com/player/193246/lamar-neagle/...
# 12492     223686  https://sofifa.com/player/223686/timon-wellenr...
# 13247     224656   https://sofifa.com/player/224656/ola-aina/150002
# ...          ...                                                ...
# 14346     223702  https://sofifa.com/player/223702/eray-seyyal/1...
# 3844      171089  https://sofifa.com/player/171089/ruben-ramirez...
# 279       163419  https://sofifa.com/player/163419/bacary-sagna/...
# 12690     200283  https://sofifa.com/player/200283/manuel-sutter...
# 7327      192114  https://sofifa.com/player/192114/antonio-brise...
#
#              short_name                         long_name  age         dob  \
# 10226   L. Augustinsson               Ludwig Augustinsson   20  1994-04-21
# 640          M. Flamini                   Mathieu Flamini   30  1984-03-07
# 4351          L. Neagle                      Lamar Neagle   27  1987-05-07
# 12492  T. Wellenreuther               Timon Wellenreuther   18  1995-12-03
# 13247           O. Aina  Temitayo Olufisayo Olaoluwa Aina   17  1996-10-08
# ...                 ...                               ...  ...         ...
# 14346         E. Seyyal                       Eray Seyyal   19  1995-01-25
# 3844         R. Ramírez               Rubén Darío Ramírez   31  1982-10-17
# 279            B. Sagna                      Bacary Sagna   31  1983-02-14
# 12690         M. Sutter                     Manuel Sutter   23  1991-03-08
# 7327         A. Briseño           Antonio Briseño Vázquez   20  1994-02-05
#
#        height_cm  weight_kg    nationality            club_name  ...  \
# 10226        181         76         Sweden         IFK Göteborg  ...
# 640          178         67         France              Arsenal  ...
# 4351         180         75  United States  Seattle Sounders FC  ...
# 12492        186         80        Germany        FC Schalke 04  ...
# 13247        175         65        England              Chelsea  ...
# ...          ...        ...            ...                  ...  ...
# 14346        180         79         Turkey         Kasimpaşa SK  ...
# 3844         185         87      Argentina           Godoy Cruz  ...
# 279          176         72         France      Manchester City  ...
# 12690        178         76        Austria             FC Vaduz  ...
# 7327         185         75         Mexico      Tigres U.A.N.L.  ...
#
#       mentality_penalties  mentality_composure  defending_marking  \
# 10226                  40                  NaN                 64
# 640                    60                  NaN                 80
# 4351                   47                  NaN                 61
# 12492                  26                  NaN                 25
# 13247                  48                  NaN                 57
# ...                   ...                  ...                ...
# 14346                  27                  NaN                 25
# 3844                   75                  NaN                 25
# 279                    58                  NaN                 81
# 12690                  53                  NaN                 39
# 7327                   53                  NaN                 65
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 10226                         63                        51
# 640                           78                        76
# 4351                          50                        47
# 12492                         25                        25
# 13247                         61                        62
# ...                          ...                       ...
# 14346                         25                        25
# 3844                          29                        25
# 279                           83                        84
# 12690                         49                        38
# 7327                          64                        55
#
#        goalkeeping_diving goalkeeping_handling goalkeeping_kicking  \
# 10226                   9                   11                   9
# 640                     6                   11                   5
# 4351                    9                   13                  15
# 12492                  62                   58                  56
# 13247                   6                   13                   9
# ...                   ...                  ...                 ...
# 14346                  61                   51                  56
# 3844                    5                   12                  15
# 279                    10                    8                   6
# 12690                   7                   11                  14
# 7327                    6                   15                  13
#
#        goalkeeping_positioning  goalkeeping_reflexes
# 10226                       14                     7
# 640                          5                     6
# 4351                         9                    13
# 12492                       52                    62
# 13247                        9                     8
# ...                        ...                   ...
# 14346                       48                    62
# 3844                        15                     5
# 279                          8                     8
# 12690                        5                    13
# 7327                         5                     9
#
# [200 rows x 80 columns]

# %% [markdown]
# I am taking 25% of the FIFA dataset here:

# %%
df.sample(frac = 0.25)
# Out:
#        sofifa_id                                         player_url  \
# 7985       11800  https://sofifa.com/player/11800/chris-weale/15...
# 3408      184587  https://sofifa.com/player/184587/tomasz-kupisz...
# 8355      212476  https://sofifa.com/player/212476/alvaro-medran...
# 8869      214996  https://sofifa.com/player/214996/matias-miraba...
# 9204      186937  https://sofifa.com/player/186937/andres-lamas/...
# ...          ...                                                ...
# 5864      210361  https://sofifa.com/player/210361/bruno-godeau/...
# 11334     212816  https://sofifa.com/player/212816/jun-gang-park...
# 3891      187705  https://sofifa.com/player/187705/edwin-hernand...
# 13092     180181  https://sofifa.com/player/180181/kenneth-brown...
# 5309      155757  https://sofifa.com/player/155757/martin-ornsko...
#
#           short_name                       long_name  age         dob  \
# 7985        C. Weale                     Chris Weale   32  1982-02-09
# 3408       T. Kupisz                   Tomasz Kupisz   24  1990-01-02
# 8355          Medrán              Álvaro Medrán Just   20  1994-03-15
# 8869     M. Mirabaje  Claudio Matías Mirabaje Correa   25  1989-03-06
# 9204        A. Lamas         Andrés Lamas Bervejillo   30  1984-01-16
# ...              ...                             ...  ...         ...
# 5864       B. Godeau                    Bruno Godeau   22  1992-05-10
# 11334  Park Jun Gang                         박준강 朴俊刚   23  1991-06-06
# 3891    E. Hernández           Juan Hernández García   27  1986-07-10
# 13092      K. Browne                  Kenneth Browne   27  1986-08-07
# 5309      M. Ørnskov                  Martin Ørnskov   28  1985-10-10
#
#        height_cm  weight_kg          nationality               club_name  ...  \
# 7985         188         84              England             Yeovil Town  ...
# 3408         180         76               Poland           Chievo Verona  ...
# 8355         176         68                Spain             Real Madrid  ...
# 8869         179         79              Uruguay  San Lorenzo de Almagro  ...
# 9204         189         81              Uruguay               FC Luzern  ...
# ...          ...        ...                  ...                     ...  ...
# 5864         190         78              Belgium            KVC Westerlo  ...
# 11334        174         69       Korea Republic             Busan IPark  ...
# 3891         166         68               Mexico               Club León  ...
# 13092        191         86  Republic of Ireland  St. Patrick's Athletic  ...
# 5309         185         80              Denmark              Brøndby IF  ...
#
#       mentality_penalties  mentality_composure  defending_marking  \
# 7985                   25                  NaN                 25
# 3408                   61                  NaN                 35
# 8355                   60                  NaN                 58
# 8869                   51                  NaN                 37
# 9204                   41                  NaN                 65
# ...                   ...                  ...                ...
# 5864                   34                  NaN                 64
# 11334                  62                  NaN                 62
# 3891                   53                  NaN                 67
# 13092                  35                  NaN                 60
# 5309                   39                  NaN                 66
#
#        defending_standing_tackle  defending_sliding_tackle  \
# 7985                          25                        25
# 3408                          50                        56
# 8355                          54                        62
# 8869                          53                        42
# 9204                          67                        59
# ...                          ...                       ...
# 5864                          76                        63
# 11334                         63                        53
# 3891                          69                        68
# 13092                         58                        57
# 5309                          66                        62
#
#        goalkeeping_diving goalkeeping_handling goalkeeping_kicking  \
# 7985                   68                   60                  61
# 3408                    7                    9                  13
# 8355                   12                   13                  12
# 8869                   15                    8                   7
# 9204                    5                    6                  10
# ...                   ...                  ...                 ...
# 5864                   13                   10                   6
# 11334                  13                   10                  15
# 3891                    6                   10                   7
# 13092                  12                   10                  13
# 5309                   12                    6                  15
#
#        goalkeeping_positioning  goalkeeping_reflexes
# 7985                        65                    66
# 3408                        13                    10
# 8355                        11                     9
# 8869                         5                     5
# 9204                         6                     5
# ...                        ...                   ...
# 5864                         8                     9
# 11334                        6                    10
# 3891                        10                    11
# 13092                       11                    12
# 5309                        14                    15
#
# [4039 rows x 80 columns]

# %% [markdown]
# **13. df[‘’].where()**
#
# This function helps you query a dataset based on a boolean condition. For an example, the random_col we made before has the values ranging from 0 to 100. Here is how we make a series to see which of them are bigger than 50.

# %%
df['random_col'].where(df['random_col'] > 50)
# Out:
# 0        75.0
# 1        96.0
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 16150     NaN
# 16151     NaN
# 16152    69.0
# 16153    84.0
# 16154     NaN
# Name: random_col, Length: 16155, dtype: float64

# %% [markdown]
# Look, where the values do not meet the condition that means the value is not greater than 50, returns NaN. We can replace NaN with 0 or any other value using this syntax:

# %%
df['random_col'].where(df['random_col'] > 50, 0)
# Out:
# 0        75
# 1        96
# 2         0
# 3         0
# 4         0
#          ..
# 16150     0
# 16151     0
# 16152    69
# 16153    84
# 16154     0
# Name: random_col, Length: 16155, dtype: int64

# %% [markdown]
# **14. df[‘’].unique()**
#
# This is very useful where we have categorical variables. It is used to find out the unique values of a categorical column. Let’s see what are the unique values of the ‘skill_moves’ column in our FIFA dataset:

# %%
df.skill_moves.unique()
# Out:
# array([4, 5, 1, 3, 2])

# %% [markdown]
# So, we have five unique values in the skill_moves columns. If we print out the head of the dataset to check out the values of the columns you may not see all the unique values in it. So, to know all the unique values .unique() function comes out really handy.
#
# **15. df[‘’].nunique()**
#
# Another popular function. This function lets you know how many unique values do you have in a column. As an example, if you want to see how many different nationalities are there in this dataset, you can use this simple line of code

# %%
df.nationality.nunique()
# Out:
# 5

# %% [markdown]
# The great thing is, this function can be used on the total dataset as well to know the number of unique values in each column:

# %%
df.nunique()
# Out:
# sofifa_id                  16155
# player_url                 16155
# short_name                 15195
# long_name                  16104
# age                           29
#                            ...
# goalkeeping_diving            73
# goalkeeping_handling          73
# goalkeeping_kicking           74
# goalkeeping_positioning       74
# goalkeeping_reflexes          74
# Length: 80, dtype: int64

# %% [markdown]
# **16. df[‘’].rank()**
#
# This function provides you with the rank based on a certain column. In the FIFA dataset, if we want to rank the players based on the ‘value_eur’ column, here is the syntax for that:

# %% [markdown]
# Here we have the number of unique values in each column.

# %%
df['rank_calc'] = df["value_eur"].rank()

# %% [markdown]
# Using the line of code above, I created a new column named ‘rank_calc’. This new column will give you the ranks of each player based on the ‘value_eur’. The column will be added at the end by default. Please run the line of code by yourself to check.

# %% [markdown]
# **17. .isin()**
#
# I am going to make a subset of the dataset that will contain only a few nationalities of players using .isin() function.

# %%
nationality = ["Argentina", "Portugal", "Sweden", "England"]
df[df.nationality.isin(nationality)]
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 23        183898  https://sofifa.com/player/183898/angel-di-mari...
# 26        153079  https://sofifa.com/player/153079/sergio-aguero...
# ...          ...                                                ...
# 16143     220549  https://sofifa.com/player/220549/liam-davies/1...
# 16145      11728  https://sofifa.com/player/11728/barry-richards...
# 16146     211228  https://sofifa.com/player/211228/matthew-palme...
# 16149     214725  https://sofifa.com/player/214725/sam-ramsbotto...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 23           A. Di María      Ángel Fabián Di María Hernández   26
# 26             S. Agüero    Sergio Leonel Agüero del Castillo   26
# ...                  ...                                  ...  ...
# 16143          L. Davies                          Liam Davies   17
# 16145      B. Richardson                     Barry Richardson   44
# 16146          M. Palmer                       Matthew Palmer   18
# 16149      S. Ramsbottom                       Sam Ramsbottom   18
# 16153          T. Davies                           Tom Davies   22
#
#               dob  height_cm  weight_kg nationality            club_name  ...  \
# 0      1987-06-24        169         67   Argentina         FC Barcelona  ...
# 1      1985-02-05        185         80    Portugal          Real Madrid  ...
# 3      1981-10-03        195         95      Sweden  Paris Saint-Germain  ...
# 23     1988-02-14        180         70   Argentina    Manchester United  ...
# 26     1988-06-02        172         74   Argentina      Manchester City  ...
# ...           ...        ...        ...         ...                  ...  ...
# 16143  1996-07-02        183         70     England      Tranmere Rovers  ...
# 16145  1969-08-05        185         77     England    Wycombe Wanderers  ...
# 16146  1995-08-01        179         79     England        Burton Albion  ...
# 16149  1996-04-03        196         80     England      Tranmere Rovers  ...
# 16153  1992-04-18        180         70     England       Fleetwood Town  ...
#
#       mentality_composure  defending_marking  defending_standing_tackle  \
# 0                     NaN                 25                         21
# 1                     NaN                 22                         31
# 3                     NaN                 25                         41
# 23                    NaN                 42                         63
# 26                    NaN                 25                         20
# ...                   ...                ...                        ...
# 16143                 NaN                 25                         25
# 16145                 NaN                 25                         25
# 16146                 NaN                 41                         58
# 16149                 NaN                 25                         25
# 16153                 NaN                 36                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                   6                    11
# 1                            23                   7                    11
# 3                            27                  13                    15
# 23                           61                  10                     7
# 26                           25                  13                    15
# ...                         ...                 ...                   ...
# 16143                        25                   7                    14
# 16145                        25                  35                    53
# 16146                        53                   8                     9
# 16149                        25                  50                    36
# 16153                        35                  15                    13
#
#       goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                      15                      14                     8
# 1                      15                      14                    11
# 3                      10                       9                    12
# 23                     11                      12                    11
# 26                      6                      11                    14
# ...                   ...                     ...                   ...
# 16143                  11                      12                    13
# 16145                  21                      57                    31
# 16146                   6                      12                    10
# 16149                  44                      41                    44
# 16153                   6                      11                     9
#
#        rank_calc
# 0        16155.0
# 1        16154.0
# 3        16151.0
# 23       16147.5
# 26       16147.5
# ...          ...
# 16143      584.0
# 16145      328.0
# 16146      584.0
# 16149      418.0
# 16153      337.5
#
# [3229 rows x 81 columns]

# %% [markdown]
# If you run this code you will see we have the resulting dataset containing only those few countries mentioned in the list above.
#
# **18. df.replace()**
#
# It does exactly what it sounds like. It replaces the values of a column. When we need to replace only one unique value of a column we simply need to pass the old value and the new value. Imagine, we just found out that the ‘league_rank’ 1.0 needs to be replaced by 1.1 now.

# %%
df.replace(1.0, 1.1)
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4               M. Neuer                         Manuel Neuer   28
# ...                  ...                                  ...  ...
# 16150          E. Redman                         Ellis Redman   17
# 16151         A. Collins                        Aaron Collins   17
# 16152           P. Żemło                          Piotr Żemło   18
# 16153          T. Davies                           Tom Davies   22
# 16154         P. Tisdale                         Paul Tisdale   41
#
#               dob  height_cm  weight_kg  nationality            club_name  \
# 0      1987-06-24        169         67    Argentina         FC Barcelona
# 1      1985-02-05        185         80     Portugal          Real Madrid
# 2      1984-01-23        180         80  Netherlands    FC Bayern München
# 3      1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4      1986-03-27        193         92      Germany    FC Bayern München
# ...           ...        ...        ...          ...                  ...
# 16150  1996-09-26        187         81        Wales       Newport County
# 16151  1997-06-01        178         57        Wales       Newport County
# 16152  1995-07-10        190         76       Poland         Wisła Kraków
# 16153  1992-04-18        180         70      England       Fleetwood Town
# 16154  1973-01-14        175         72        Malta          Exeter City
#
#        ... mentality_composure  defending_marking  defending_standing_tackle  \
# 0      ...                 NaN                 25                         21
# 1      ...                 NaN                 22                         31
# 2      ...                 NaN                 29                         26
# 3      ...                 NaN                 25                         41
# 4      ...                 NaN                 25                         25
# ...    ...                 ...                ...                        ...
# 16150  ...                 NaN                 38                         40
# 16151  ...                 NaN                 25                         25
# 16152  ...                 NaN                 54                         52
# 16153  ...                 NaN                 36                         34
# 16154  ...                 NaN                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                 6.0                  11.0
# 1                            23                 7.0                  11.0
# 2                            26                10.0                   8.0
# 3                            27                13.0                  15.0
# 4                            25                87.0                  85.0
# ...                         ...                 ...                   ...
# 16150                        35                12.0                   6.0
# 16151                        25                13.0                  11.0
# 16152                        51                 8.0                  14.0
# 16153                        35                15.0                  13.0
# 16154                        29                 5.0                   6.0
#
#       goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                    15.0                    14.0                   8.0
# 1                    15.0                    14.0                  11.0
# 2                    11.0                     5.0                  15.0
# 3                    10.0                     9.0                  12.0
# 4                    92.0                    90.0                  86.0
# ...                   ...                     ...                   ...
# 16150                15.0                     8.0                   6.0
# 16151                12.0                    15.0                  11.0
# 16152                 7.0                    10.0                   9.0
# 16153                 6.0                    11.0                   9.0
# 16154                14.0                     8.0                  13.0
#
#        rank_calc
# 0        16155.0
# 1        16154.0
# 2        16152.0
# 3        16151.0
# 4        16153.0
# ...          ...
# 16150      418.0
# 16151      749.5
# 16152      337.5
# 16153      337.5
# 16154      156.0
#
# [16155 rows x 81 columns]

# %% [markdown]
# Look at the league_rank column in the dataset now, 1.0 is replaced by 1.1. If we need to change more than one value, we can pass a dictionary to the replace function where the key should be the original value and the value should be the replacement.

# %%
df.replace({1.0: 1.1,  4.0: 4.1, 3.0: 3.1})
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4               M. Neuer                         Manuel Neuer   28
# ...                  ...                                  ...  ...
# 16150          E. Redman                         Ellis Redman   17
# 16151         A. Collins                        Aaron Collins   17
# 16152           P. Żemło                          Piotr Żemło   18
# 16153          T. Davies                           Tom Davies   22
# 16154         P. Tisdale                         Paul Tisdale   41
#
#               dob  height_cm  weight_kg  nationality            club_name  \
# 0      1987-06-24        169         67    Argentina         FC Barcelona
# 1      1985-02-05        185         80     Portugal          Real Madrid
# 2      1984-01-23        180         80  Netherlands    FC Bayern München
# 3      1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4      1986-03-27        193         92      Germany    FC Bayern München
# ...           ...        ...        ...          ...                  ...
# 16150  1996-09-26        187         81        Wales       Newport County
# 16151  1997-06-01        178         57        Wales       Newport County
# 16152  1995-07-10        190         76       Poland         Wisła Kraków
# 16153  1992-04-18        180         70      England       Fleetwood Town
# 16154  1973-01-14        175         72        Malta          Exeter City
#
#        ... mentality_composure  defending_marking  defending_standing_tackle  \
# 0      ...                 NaN                 25                         21
# 1      ...                 NaN                 22                         31
# 2      ...                 NaN                 29                         26
# 3      ...                 NaN                 25                         41
# 4      ...                 NaN                 25                         25
# ...    ...                 ...                ...                        ...
# 16150  ...                 NaN                 38                         40
# 16151  ...                 NaN                 25                         25
# 16152  ...                 NaN                 54                         52
# 16153  ...                 NaN                 36                         34
# 16154  ...                 NaN                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                 6.0                  11.0
# 1                            23                 7.0                  11.0
# 2                            26                10.0                   8.0
# 3                            27                13.0                  15.0
# 4                            25                87.0                  85.0
# ...                         ...                 ...                   ...
# 16150                        35                12.0                   6.0
# 16151                        25                13.0                  11.0
# 16152                        51                 8.0                  14.0
# 16153                        35                15.0                  13.0
# 16154                        29                 5.0                   6.0
#
#       goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                    15.0                    14.0                   8.0
# 1                    15.0                    14.0                  11.0
# 2                    11.0                     5.0                  15.0
# 3                    10.0                     9.0                  12.0
# 4                    92.0                    90.0                  86.0
# ...                   ...                     ...                   ...
# 16150                15.0                     8.0                   6.0
# 16151                12.0                    15.0                  11.0
# 16152                 7.0                    10.0                   9.0
# 16153                 6.0                    11.0                   9.0
# 16154                14.0                     8.0                  13.0
#
#        rank_calc
# 0        16155.0
# 1        16154.0
# 2        16152.0
# 3        16151.0
# 4        16153.0
# ...          ...
# 16150      418.0
# 16151      749.5
# 16152      337.5
# 16153      337.5
# 16154      156.0
#
# [16155 rows x 81 columns]

# %% [markdown]
# **19. df.rename()**
#
# It is used to rename the column/s. Here I am changing the ‘weight_kg’ and ‘height_cm’ columns to “Weight (kg)” and “Height (cm)”:

# %%
df.rename(columns = {"weight_kg": "Weight (kg)", "height_cm": "Height (cm)"})
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4               M. Neuer                         Manuel Neuer   28
# ...                  ...                                  ...  ...
# 16150          E. Redman                         Ellis Redman   17
# 16151         A. Collins                        Aaron Collins   17
# 16152           P. Żemło                          Piotr Żemło   18
# 16153          T. Davies                           Tom Davies   22
# 16154         P. Tisdale                         Paul Tisdale   41
#
#               dob  Height (cm)  Weight (kg)  nationality            club_name  \
# 0      1987-06-24          169           67    Argentina         FC Barcelona
# 1      1985-02-05          185           80     Portugal          Real Madrid
# 2      1984-01-23          180           80  Netherlands    FC Bayern München
# 3      1981-10-03          195           95       Sweden  Paris Saint-Germain
# 4      1986-03-27          193           92      Germany    FC Bayern München
# ...           ...          ...          ...          ...                  ...
# 16150  1996-09-26          187           81        Wales       Newport County
# 16151  1997-06-01          178           57        Wales       Newport County
# 16152  1995-07-10          190           76       Poland         Wisła Kraków
# 16153  1992-04-18          180           70      England       Fleetwood Town
# 16154  1973-01-14          175           72        Malta          Exeter City
#
#        ... mentality_composure  defending_marking  defending_standing_tackle  \
# 0      ...                 NaN                 25                         21
# 1      ...                 NaN                 22                         31
# 2      ...                 NaN                 29                         26
# 3      ...                 NaN                 25                         41
# 4      ...                 NaN                 25                         25
# ...    ...                 ...                ...                        ...
# 16150  ...                 NaN                 38                         40
# 16151  ...                 NaN                 25                         25
# 16152  ...                 NaN                 54                         52
# 16153  ...                 NaN                 36                         34
# 16154  ...                 NaN                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                   6                    11
# 1                            23                   7                    11
# 2                            26                  10                     8
# 3                            27                  13                    15
# 4                            25                  87                    85
# ...                         ...                 ...                   ...
# 16150                        35                  12                     6
# 16151                        25                  13                    11
# 16152                        51                   8                    14
# 16153                        35                  15                    13
# 16154                        29                   5                     6
#
#       goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                      15                      14                     8
# 1                      15                      14                    11
# 2                      11                       5                    15
# 3                      10                       9                    12
# 4                      92                      90                    86
# ...                   ...                     ...                   ...
# 16150                  15                       8                     6
# 16151                  12                      15                    11
# 16152                   7                      10                     9
# 16153                   6                      11                     9
# 16154                  14                       8                    13
#
#        rank_calc
# 0        16155.0
# 1        16154.0
# 2        16152.0
# 3        16151.0
# 4        16153.0
# ...          ...
# 16150      418.0
# 16151      749.5
# 16152      337.5
# 16153      337.5
# 16154      156.0
#
# [16155 rows x 81 columns]

# %% [markdown]
# **20. .fillna()**
#
# Whenever you will receive a big dataset in real life, there will be some null values in most cases. It is really hard to get a perfect dataset. So, filling up the null values is part of your daily task if you are a data analyst or a data scientist. This function .fillna() replaces the null values with some other value of your choice. Here are some of the columns towards the end of the FIFA dataset:

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4               M. Neuer                         Manuel Neuer   28
# ...                  ...                                  ...  ...
# 16150          E. Redman                         Ellis Redman   17
# 16151         A. Collins                        Aaron Collins   17
# 16152           P. Żemło                          Piotr Żemło   18
# 16153          T. Davies                           Tom Davies   22
# 16154         P. Tisdale                         Paul Tisdale   41
#
#               dob  height_cm  weight_kg  nationality            club_name  \
# 0      1987-06-24        169         67    Argentina         FC Barcelona
# 1      1985-02-05        185         80     Portugal          Real Madrid
# 2      1984-01-23        180         80  Netherlands    FC Bayern München
# 3      1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4      1986-03-27        193         92      Germany    FC Bayern München
# ...           ...        ...        ...          ...                  ...
# 16150  1996-09-26        187         81        Wales       Newport County
# 16151  1997-06-01        178         57        Wales       Newport County
# 16152  1995-07-10        190         76       Poland         Wisła Kraków
# 16153  1992-04-18        180         70      England       Fleetwood Town
# 16154  1973-01-14        175         72        Malta          Exeter City
#
#        ... mentality_composure  defending_marking  defending_standing_tackle  \
# 0      ...                 NaN                 25                         21
# 1      ...                 NaN                 22                         31
# 2      ...                 NaN                 29                         26
# 3      ...                 NaN                 25                         41
# 4      ...                 NaN                 25                         25
# ...    ...                 ...                ...                        ...
# 16150  ...                 NaN                 38                         40
# 16151  ...                 NaN                 25                         25
# 16152  ...                 NaN                 54                         52
# 16153  ...                 NaN                 36                         34
# 16154  ...                 NaN                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                   6                    11
# 1                            23                   7                    11
# 2                            26                  10                     8
# 3                            27                  13                    15
# 4                            25                  87                    85
# ...                         ...                 ...                   ...
# 16150                        35                  12                     6
# 16151                        25                  13                    11
# 16152                        51                   8                    14
# 16153                        35                  15                    13
# 16154                        29                   5                     6
#
#       goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                      15                      14                     8
# 1                      15                      14                    11
# 2                      11                       5                    15
# 3                      10                       9                    12
# 4                      92                      90                    86
# ...                   ...                     ...                   ...
# 16150                  15                       8                     6
# 16151                  12                      15                    11
# 16152                   7                      10                     9
# 16153                   6                      11                     9
# 16154                  14                       8                    13
#
#        rank_calc
# 0        16155.0
# 1        16154.0
# 2        16152.0
# 3        16151.0
# 4        16153.0
# ...          ...
# 16150      418.0
# 16151      749.5
# 16152      337.5
# 16153      337.5
# 16154      156.0
#
# [16155 rows x 81 columns]

# %% [markdown]
# Look, there are some null values in shooting, passing, defending, and some other columns. We really need to replace those null values with some values of compatible data types before we start doing any predictive modeling and also some other data science tasks. Otherwise, we may get errors. For example in the ‘pace’ column, the values should be numeric but here and there you will see NaN values. The most generic but not so efficient way is to replace those NaN values with zeros. Here is the way to change the all the NaN values of the ‘pace’ column with zeros:

# %%
df['mentality_composure'].fillna(0, inplace=True)

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4               M. Neuer                         Manuel Neuer   28
# ...                  ...                                  ...  ...
# 16150          E. Redman                         Ellis Redman   17
# 16151         A. Collins                        Aaron Collins   17
# 16152           P. Żemło                          Piotr Żemło   18
# 16153          T. Davies                           Tom Davies   22
# 16154         P. Tisdale                         Paul Tisdale   41
#
#               dob  height_cm  weight_kg  nationality            club_name  \
# 0      1987-06-24        169         67    Argentina         FC Barcelona
# 1      1985-02-05        185         80     Portugal          Real Madrid
# 2      1984-01-23        180         80  Netherlands    FC Bayern München
# 3      1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4      1986-03-27        193         92      Germany    FC Bayern München
# ...           ...        ...        ...          ...                  ...
# 16150  1996-09-26        187         81        Wales       Newport County
# 16151  1997-06-01        178         57        Wales       Newport County
# 16152  1995-07-10        190         76       Poland         Wisła Kraków
# 16153  1992-04-18        180         70      England       Fleetwood Town
# 16154  1973-01-14        175         72        Malta          Exeter City
#
#        ... mentality_composure  defending_marking  defending_standing_tackle  \
# 0      ...                 0.0                 25                         21
# 1      ...                 0.0                 22                         31
# 2      ...                 0.0                 29                         26
# 3      ...                 0.0                 25                         41
# 4      ...                 0.0                 25                         25
# ...    ...                 ...                ...                        ...
# 16150  ...                 0.0                 38                         40
# 16151  ...                 0.0                 25                         25
# 16152  ...                 0.0                 54                         52
# 16153  ...                 0.0                 36                         34
# 16154  ...                 0.0                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                   6                    11
# 1                            23                   7                    11
# 2                            26                  10                     8
# 3                            27                  13                    15
# 4                            25                  87                    85
# ...                         ...                 ...                   ...
# 16150                        35                  12                     6
# 16151                        25                  13                    11
# 16152                        51                   8                    14
# 16153                        35                  15                    13
# 16154                        29                   5                     6
#
#       goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                      15                      14                     8
# 1                      15                      14                    11
# 2                      11                       5                    15
# 3                      10                       9                    12
# 4                      92                      90                    86
# ...                   ...                     ...                   ...
# 16150                  15                       8                     6
# 16151                  12                      15                    11
# 16152                   7                      10                     9
# 16153                   6                      11                     9
# 16154                  14                       8                    13
#
#        rank_calc
# 0        16155.0
# 1        16154.0
# 2        16152.0
# 3        16151.0
# 4        16153.0
# ...          ...
# 16150      418.0
# 16151      749.5
# 16152      337.5
# 16153      337.5
# 16154      156.0
#
# [16155 rows x 81 columns]

# %% [markdown]
# If you notice, the NaN in the pace column is zero now. In the total pace column, if there are more NaN values they should also be replaced by zeros.
#
# As I mentioned before replacing by zero may not be the most efficient way. You can replace it with some other value of your choice. It is also common to replace values with the mean or median. If we wanted to replace the NaN values of the pace column with the mean of space column we would have used this line of code instead:

# %%
df['pace'].fillna(df['pace'].mean(), inplace = True)

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16152     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2              A. Robben                         Arjen Robben   30
# 3         Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4               M. Neuer                         Manuel Neuer   28
# ...                  ...                                  ...  ...
# 16150          E. Redman                         Ellis Redman   17
# 16151         A. Collins                        Aaron Collins   17
# 16152           P. Żemło                          Piotr Żemło   18
# 16153          T. Davies                           Tom Davies   22
# 16154         P. Tisdale                         Paul Tisdale   41
#
#               dob  height_cm  weight_kg  nationality            club_name  \
# 0      1987-06-24        169         67    Argentina         FC Barcelona
# 1      1985-02-05        185         80     Portugal          Real Madrid
# 2      1984-01-23        180         80  Netherlands    FC Bayern München
# 3      1981-10-03        195         95       Sweden  Paris Saint-Germain
# 4      1986-03-27        193         92      Germany    FC Bayern München
# ...           ...        ...        ...          ...                  ...
# 16150  1996-09-26        187         81        Wales       Newport County
# 16151  1997-06-01        178         57        Wales       Newport County
# 16152  1995-07-10        190         76       Poland         Wisła Kraków
# 16153  1992-04-18        180         70      England       Fleetwood Town
# 16154  1973-01-14        175         72        Malta          Exeter City
#
#        ... mentality_composure  defending_marking  defending_standing_tackle  \
# 0      ...                 NaN                 25                         21
# 1      ...                 NaN                 22                         31
# 2      ...                 NaN                 29                         26
# 3      ...                 NaN                 25                         41
# 4      ...                 NaN                 25                         25
# ...    ...                 ...                ...                        ...
# 16150  ...                 NaN                 38                         40
# 16151  ...                 NaN                 25                         25
# 16152  ...                 NaN                 54                         52
# 16153  ...                 NaN                 36                         34
# 16154  ...                 NaN                 27                         34
#
#        defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                            20                   6                    11
# 1                            23                   7                    11
# 2                            26                  10                     8
# 3                            27                  13                    15
# 4                            25                  87                    85
# ...                         ...                 ...                   ...
# 16150                        35                  12                     6
# 16151                        25                  13                    11
# 16152                        51                   8                    14
# 16153                        35                  15                    13
# 16154                        29                   5                     6
#
#       goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  \
# 0                      15                      14                     8
# 1                      15                      14                    11
# 2                      11                       5                    15
# 3                      10                       9                    12
# 4                      92                      90                    86
# ...                   ...                     ...                   ...
# 16150                  15                       8                     6
# 16151                  12                      15                    11
# 16152                   7                      10                     9
# 16153                   6                      11                     9
# 16154                  14                       8                    13
#
#        rank_calc
# 0        16155.0
# 1        16154.0
# 2        16152.0
# 3        16151.0
# 4        16153.0
# ...          ...
# 16150      418.0
# 16151      749.5
# 16152      337.5
# 16153      337.5
# 16154      156.0
#
# [16155 rows x 81 columns]

# %% [markdown]
# **21. df.groupby()**
#
# This is the most popular function for data summarizing. You can group the data as per a certain variable and find out useful information about those groups. For example, here I am grouping the data by nationality and calculating the total ‘value_eur’ for each nationality:

# %%
df.groupby("nationality")['value_eur'].sum()
# Out:
# nationality
# Albania                25860000
# Algeria                70560000
# Angola                  6070000
# Antigua & Barbuda       1450000
# Argentina            1281372000
#                         ...
# Uzbekistan              7495000
# Venezuela              41495000
# Wales                 113340000
# Zambia                  4375000
# Zimbabwe                6000000
# Name: value_eur, Length: 149, dtype: int64

# %% [markdown]
# The sum of ‘value_eur’ for all the players of Albania is 25860000.
#
# It is also possible to group by several variables and use several aggregate functions. We will see for each nationality and each league rank’s mean value_eur, median value_eur, mean wage_eur, and median wage_eur.

# %%
df.groupby(['nationality', 'league_rank'])['value_eur', 'wage_eur'].agg([np.mean, np.median])
# Out:
# <ipython-input-48-937bad2019bf>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(['nationality', 'league_rank'])['value_eur', 'wage_eur'].agg([np.mean, np.median])
#                             value_eur                 wage_eur
#                                  mean     median          mean   median
# nationality league_rank
# Albania     1.0          8.584615e+05   475000.0  13230.769231   7000.0
#             2.0          5.057143e+05   500000.0   5857.142857   7000.0
# Algeria     1.0          2.130536e+06  1300000.0  25107.142857  20000.0
#             2.0          8.388462e+05   450000.0  12307.692308   8000.0
# Angola      1.0          1.149000e+06   575000.0  15600.000000   9000.0
# ...                               ...        ...           ...      ...
# Zambia      1.0          9.583333e+05   925000.0  11000.000000   9000.0
#             2.0          1.500000e+06  1500000.0  20000.000000  20000.0
# Zimbabwe    1.0          6.183333e+05   500000.0   8777.777778   9000.0
#             3.0          2.025000e+05   202500.0   3500.000000   3500.0
#             4.0          3.000000e+04    30000.0   2000.000000   2000.0
#
# [318 rows x 4 columns]

# %% [markdown]
# **22. .pct_change()**
#
# You can get the percent change from the previous value of a variable. For this demonstration, I will use the value_eur column and get the percent change from the previous for each row of data. The first row will be NaN because there is no value to compare before.

# %%
df.value_eur.pct_change()
# Out:
# 0             NaN
# 1       -0.213930
# 2       -0.310127
# 3       -0.036697
# 4        0.209524
#            ...
# 16150    0.000000
# 16151    0.500000
# 16152   -0.500000
# 16153    0.000000
# 16154   -1.000000
# Name: value_eur, Length: 16155, dtype: float64

# %% [markdown]
# **23. df.count()**
#
#
# It provides you the number of data in the DataFrame in the specified direction. When the direction is 0, it provides the number of data in the columns:

# %%
df.count(0)
# Out:
# sofifa_id                  16155
# player_url                 16155
# short_name                 16155
# long_name                  16155
# age                        16155
#                            ...
# goalkeeping_handling       16155
# goalkeeping_kicking        16155
# goalkeeping_positioning    16155
# goalkeeping_reflexes       16155
# rank_calc                  16155
# Length: 81, dtype: int64

# %% [markdown]
# You can see the number of data in each column.
#
# When the direction is 1, it provides the number of data in the rows:

# %%
df.count(1)
# Out:
# 0        72
# 1        72
# 2        72
# 3        72
# 4        72
#          ..
# 16150    68
# 16151    68
# 16152    68
# 16153    68
# 16154    69
# Length: 16155, dtype: int64

# %% [markdown]
# As you can see, each row does not have the same number of data. If you observe the dataset carefully, you will see that it has a lot of null values in several columns.

# %% [markdown]
# **24. df[‘’].value_counts()**
#
# We can get the value counts of each category using this function. Here I am getting how many values are there in each league_rank.

# %%
df['league_rank'].value_counts()
# Out:
# 1.0    11738
# 2.0     2936
# 3.0      639
# 4.0      603
# Name: league_rank, dtype: int64

# %% [markdown]
# It returns the result sorted by default. If you want the result in ascending order, simply set ascending=True:

# %%
df['league_rank'].value_counts(ascending=True)
# Out:
# 4.0      603
# 3.0      639
# 2.0     2936
# 1.0    11738
# Name: league_rank, dtype: int64

# %% [markdown]
# **25. pd.crosstab()**
#
# It gives you a frequency table that is a cross-tabulation of two variables. I am making a cross-tabulation of league_rank and international_reputation here:

# %%
pd.crosstab(df['league_rank'], df['international_reputation'])
# Out:
# international_reputation      1     2    3   4  5
# league_rank
# 1.0                       10305  1160  227  37  9
# 2.0                        2772   163    1   0  0
# 3.0                         637     2    0   0  0
# 4.0                         601     2    0   0  0

# %% [markdown]
# So, we got the number count of all the combinations of league_rank and international_reputation. We can see that the majority of players have international_reputation and league_rank both 1.
#
# It can be improved further. We can add margins in both directions that will be the total and also we can get the normalized values if necessary:

# %%
pd.crosstab(df['league_rank'], df['international_reputation'],
            margins = True,
            margins_name="Total",
            normalize = True)
# Out:
# international_reputation         1         2         3         4         5  \
# league_rank
# 1.0                       0.647462  0.072883  0.014262  0.002325  0.000565
# 2.0                       0.174164  0.010241  0.000063  0.000000  0.000000
# 3.0                       0.040023  0.000126  0.000000  0.000000  0.000000
# 4.0                       0.037761  0.000126  0.000000  0.000000  0.000000
# Total                     0.899409  0.083375  0.014325  0.002325  0.000565
#
# international_reputation     Total
# league_rank
# 1.0                       0.737497
# 2.0                       0.184468
# 3.0                       0.040148
# 4.0                       0.037886
# Total                     1.000000

# %% [markdown]
# **26. pd.qcut()**
#
# This function bins the data or segments the data based on the distribution of the data. So, we get the range for each player. Here I am going to segment the value_eur in 5 portions and get which player falls in which portion:

# %%
pd.qcut(df['value_eur'], q = 5)
# Out:
# 0        (1100000.0, 100500000.0]
# 1        (1100000.0, 100500000.0]
# 2        (1100000.0, 100500000.0]
# 3        (1100000.0, 100500000.0]
# 4        (1100000.0, 100500000.0]
#                    ...
# 16150          (-0.001, 100000.0]
# 16151          (-0.001, 100000.0]
# 16152          (-0.001, 100000.0]
# 16153          (-0.001, 100000.0]
# 16154          (-0.001, 100000.0]
# Name: value_eur, Length: 16155, dtype: category
# Categories (5, interval[float64, right]): [(-0.001, 100000.0] < (100000.0, 230000.0] <
#                                            (230000.0, 500000.0] < (500000.0, 1100000.0] <
#                                            (1100000.0, 100500000.0]]

# %% [markdown]
# You can use the value_counts on the above line of code to see how players fall in which range:

# %%
pd.qcut(df['value_eur'], q = 5).value_counts()
# Out:
# (-0.001, 100000.0]          3462
# (230000.0, 500000.0]        3305
# (100000.0, 230000.0]        3184
# (500000.0, 1100000.0]       3154
# (1100000.0, 100500000.0]    3050
# Name: value_eur, dtype: int64

# %% [markdown]
# As you can see the numbers are pretty close. By default, qcut tries to divide them equally. But in real life, it doesn’t want to be equal always. Because the distribution is not uniform most of the time.
#
# **27. pd.cut()**
#
# Another method for binning. If we want to make 5 bins using cut, it will divide the entire value_eur range into equal five portions and the population in each bin will follow accordingly.

# %%
pd.cut(df['value_eur'], bins = 5).value_counts()
# Out:
# (-100500.0, 20100000.0]      16102
# (20100000.0, 40200000.0]        40
# (40200000.0, 60300000.0]        10
# (60300000.0, 80400000.0]         2
# (80400000.0, 100500000.0]        1
# Name: value_eur, dtype: int64

# %% [markdown]
# The interval in each range is equal. But the population in each group is very different.
#
# **28. df[‘’].describe()**
#
# This is a great function that provides some basic statistical measures. Here I am using the describe function on the wage_eur column

# %%
df['wage_eur'].describe()
# Out:
# count     16155.000000
# mean      13056.453110
# std       23488.182571
# min           0.000000
# 25%        2000.000000
# 50%        5000.000000
# 75%       10000.000000
# max      550000.000000
# Name: wage_eur, dtype: float64

# %% [markdown]
# As the output shows, we have eight different measures. Each of them is very significant.
#
# **29. nlargest and nsmallest**
#
# This gives you the dataset with n number of largest values or smallest values of a specified variable. As an example, I wanted to get the rows with the top 5 wage_eur:

# %%
df.nlargest(5, "wage_eur")
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
# 5          L. Suárez             Luis Alberto Suárez Díaz   27  1987-01-24
# 2          A. Robben                         Arjen Robben   30  1984-01-23
#
#    height_cm  weight_kg  nationality          club_name  ...  \
# 0        169         67    Argentina       FC Barcelona  ...
# 1        185         80     Portugal        Real Madrid  ...
# 4        193         92      Germany  FC Bayern München  ...
# 5        181         81      Uruguay       FC Barcelona  ...
# 2        180         80  Netherlands  FC Bayern München  ...
#
#   mentality_composure  defending_marking  defending_standing_tackle  \
# 0                 NaN                 25                         21
# 1                 NaN                 22                         31
# 4                 NaN                 25                         25
# 5                 NaN                 30                         45
# 2                 NaN                 29                         26
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        20                   6                    11
# 1                        23                   7                    11
# 4                        25                  87                    85
# 5                        38                  27                    25
# 2                        26                  10                     8
#
#   goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes  rank_calc
# 0                  15                      14                     8    16155.0
# 1                  15                      14                    11    16154.0
# 4                  92                      90                    86    16153.0
# 5                  31                      33                    37    16150.0
# 2                  11                       5                    15    16152.0
#
# [5 rows x 81 columns]

# %%
df.nsmallest(5, "wage_eur")
# Out:
#      sofifa_id                                         player_url  \
# 151     209119  https://sofifa.com/player/209119/francisco-amo...
# 283     178007  https://sofifa.com/player/178007/miguel-luis-p...
# 289     209097  https://sofifa.com/player/209097/omar-luis-car...
# 424     209102  https://sofifa.com/player/209102/marco-aurelio...
# 456     178416  https://sofifa.com/player/178416/jeremain-lens...
#
#          short_name                 long_name  age         dob  height_cm  \
# 151  F. Amorebielsa     Francisco Amorebielsa   28  1985-10-27        194
# 283   Miguel Veloso  Miguel Luís Pinto Veloso   28  1986-05-11        180
# 289      O. Cardosa         Omar Luis Cardosa   30  1983-11-26        188
# 424   M. Etxeberría  Marco Aurelio Etxeberría   27  1987-04-11        183
# 456         J. Lens             Jeremain Lens   26  1987-11-24        178
#
#      weight_kg  nationality club_name  ... mentality_composure  \
# 151         83    Venezuela       NaN  ...                 NaN
# 283         78     Portugal       NaN  ...                 NaN
# 289         84     Paraguay       NaN  ...                 NaN
# 424         77     Paraguay       NaN  ...                 NaN
# 456         73  Netherlands       NaN  ...                 NaN
#
#      defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 151                 81                         84                        83
# 283                 70                         78                        75
# 289                 30                         32                        34
# 424                 60                         70                        70
# 456                 21                         38                        31
#
#      goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 151                  15                     5                  12
# 283                  15                     6                   8
# 289                  12                     7                   6
# 424                  12                    12                  15
# 456                  15                    15                  13
#
#     goalkeeping_positioning  goalkeeping_reflexes  rank_calc
# 151                       6                    12      156.0
# 283                       7                    14      156.0
# 289                      14                    11      156.0
# 424                      13                     6      156.0
# 456                      14                     5      156.0
#
# [5 rows x 81 columns]

# %% [markdown]
# **30. df.explode()**
#
# Explode can be useful when you have a list of data in some rows. It is hard to analyze, visualize or perform some predictive modeling when you have integers in some columns and lists in some columns. Explode helps to break down those lists. For example, look at this DataFrame:

# %%
df1 = pd.DataFrame({"city": ['A', 'B', 'C'],
                   "day1": [22, 25, 21],
                   'day2':[31, 12, 67],
                   'day3': [27, 20, 15],
                   'day4': [34, 37, [41, 45, 67, 90, 21]],
                   'day5': [23, 54, 36]})

# %%
df1
# Out:
#   city  day1  day2  day3                  day4  day5
# 0    A    22    31    27                    34    23
# 1    B    25    12    20                    37    54
# 2    C    21    67    15  [41, 45, 67, 90, 21]    36
